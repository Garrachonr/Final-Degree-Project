# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#https://triviaquestions4u.com/multiple-choice-trivia-questions-and-answer/

# %%
#RESET THE DATAGRAME; BE CAREFULL!!!

data = {"Question" : ["prueba"], "Answer":["year"]}
post = pd.DataFrame(data)
post.to_excel("/content/drive/MyDrive/Trabajo Fin de Grado/Final-Degree-Project/Process Dataframes/Trivial.xlsx")

# %%
#Read the data
#import pandas as pd
#post = pd.read_excel("/content/drive/MyDrive/Trabajo Fin de Grado/Final-Degree-Project/Process Dataframes/Trivial.xlsx", index_col=0)
