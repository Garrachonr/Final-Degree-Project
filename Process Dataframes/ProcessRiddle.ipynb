# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#https://parade.com/947956/parade/riddles/
#https://www.adivinancero.com/rotar/rotar.html

# %%
#RESET THE DATAGRAME; BE CAREFULL!!!

data = {"Riddle" : ["prueba"], "Answer":["year"], "Adivinanza": ["prueba"], "respuesta": ["prueba"]}
post = pd.DataFrame(data)
post.to_excel("/content/drive/MyDrive/Trabajo Fin de Grado/Final-Degree-Project/Process Dataframes/Riddle.xlsx")

# %%
#Read the data
#import pandas as pd
#post = pd.read_excel("/content/drive/MyDrive/Trabajo Fin de Grado/Final-Degree-Project/Process Dataframes/Riddle.xlsx", index_col=0)
