# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install fuzzywuzzy
# !pip install transformers
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup as bs
from urllib.request import urlopen

# %%
#Usar modelo pre-entrenado

import keras

model = keras.models.load_model("/content/drive/MyDrive/Trabajo Fin de Grado/TFG/Humor Analysis/colbert-trained/")
model.summary()
# Out:
# WARNING:tensorflow:SavedModel saved prior to TF 2.5 detected when loading Keras model. Please ensure that you are saving the model with model.save() or tf.keras.models.save_model(), *NOT* tf.saved_model.save(). To confirm, there should be a file named "keras_metadata.pb" in the SavedModel directory.
# Model: "functional_3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_19 (InputLayer)          [(None, 20)]         0           []
#
#  input_20 (InputLayer)          [(None, 20)]         0           []
#
#  input_21 (InputLayer)          [(None, 20)]         0           []
#
#  input_22 (InputLayer)          [(None, 20)]         0           []
#
#  input_23 (InputLayer)          [(None, 20)]         0           []
#
#  input_24 (InputLayer)          [(None, 20)]         0           []
#
# ...

# %%
#English Jokes

#Beutifull Soup
flag = 0
page = 0

#Extract 20 jokes
while flag < 20:

  #specify URL
  if page == 0:
    url = "http://www.laughfactory.com/jokes/clean-jokes/"
  else:
    url = "http://www.laughfactory.com/jokes/clean-jokes/{}".format(page)

  #get the HTML from the page and assign it to the html variable
  html = urlopen(url)

  #parse the HTML and assign it to the variable 'soup'
  soup = bs(html.read(), 'html.parser')

  #get the text of the joke and assign to the variable "chiste"
  joke = soup.find("div", class_="jokes").text
  for jok in soup.find_all("div", class_ = "jokes"):
    #Avanzamos de pagina para la siguiente url
    page += 1
    joke = jok.find("div", class_ = "joke-text").text
    #que sean chister cortos
    if len(joke) < 300:
      escape = False
      #for chist in post.Chiste:
      #    if fuzz.ratio(chist, joke) > 80:
      #        escape = True
      if escape == False:
        if flag == 0:
          dat = {"text": [joke.strip()], "humor": True}
          jokes = pd.DataFrame(dat)
        else:   
          dat = {"text": joke.strip(), "humor": True}
          jokes = jokes.append(dat, ignore_index=True)
        flag += 1
display(jokes.head(5))
# Out:
#                                                 text  humor
# 0  Teacher: "Kids, what does the chicken give you...   True
# 1  My friend thinks he is smart. He told me an on...   True
# 2  What happens to a frog's car when it breaks do...   True
# 3  Q: Is Google male or female? A: Female, becaus...   True
# 4  Kid 1: "Hey, I bet you're still a virgin." Kid...   True

# %%
test_preds = model.predict(jokes)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-1e4282842ad0> in <module>()
# ----> 1 test_preds = model.predict(np.asarray(jokes).astype('float32'))
#
# ValueError: could not convert string to float: 'Teacher: "Kids, what does the chicken give you?"Student: "Meat!"Teacher: "Very good! Now what does the pig give you?"Student: "Bacon!"Teacher: "Great! And what does the fat cow give you?"Student: "Homework!"'
