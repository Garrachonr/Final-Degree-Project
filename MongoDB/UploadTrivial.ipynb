# %%
# !pip install pymongo[srv]
# !pip install dnspython
# !pip install pandas
# !pip install -U deep_translator
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 269 kB 3.8 MB/s
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 128 kB 8.1 MB/s
# ...
#   Attempting uninstall: beautifulsoup4
#     Found existing installation: beautifulsoup4 4.6.3
#     Uninstalling beautifulsoup4-4.6.3:
#       Successfully uninstalled beautifulsoup4-4.6.3
# ...

# %%
#TRANSLATOR
from deep_translator import GoogleTranslator
translated = GoogleTranslator(source='auto', target='es')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pymongo
from pymongo import MongoClient

client = MongoClient("mongodb+srv://garrachonr:129678@cluster0.p1uwe.mongodb.net/skill?retryWrites=true&w=majority")
db = client.Tomas
mong = db.Trivial

# %%
import pandas as pd
n = 0
data = pd.read_excel("/content/drive/MyDrive/Trabajo Fin de Grado/Final-Degree-Project/Process Dataframes/Trivial.xlsx")
for i in range(len(data)) :
  trans1 = translated.translate(data.loc[i, "Question"])
  trans2 = translated.translate(data.loc[i, "Answer"])
  prueba = {"id": n, "question":data.loc[i, "Question"], "answer":data.loc[i, "Answer"], "pregunta":trans1, "respuesta":trans2}
  mong.insert_one(prueba)
  n = n + 1
