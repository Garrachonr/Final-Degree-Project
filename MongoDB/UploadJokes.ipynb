# %%
# !pip install pymongo[srv]
# !pip install dnspython
# !pip install pandas
# Out:
# ...
#      |████████████████████████████████| 269 kB 5.2 MB/s
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pymongo
from pymongo import MongoClient

client = MongoClient("mongodb+srv://garrachonr:129678@cluster0.p1uwe.mongodb.net/skill?retryWrites=true&w=majority")
db = client.skill
mong = db.jokes

# %%
import pandas as pd
n = 0
data = pd.read_excel("/content/drive/MyDrive/Trabajo Fin de Grado/TFG/Wrappers/Jokes.xlsx", index_col=0)
for i in range(len(data)) :
  prueba = {"id": n, "joke":data.loc[i, "Joke"], "chiste":data.loc[i, "Chiste"]}
  mong.insert_one(prueba)
  n = n + 1
