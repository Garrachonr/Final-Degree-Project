# %%
# !pip install pymongo[srv]
# !pip install dnspython
# !pip install pandas
# !pip install -U deep_translator

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pymongo
from pymongo import MongoClient

client = MongoClient("mongodb+srv://garrachonr:129678@cluster0.p1uwe.mongodb.net/skill?retryWrites=true&w=majority")
db = client.Tomas
mong = db.Facts

# %%
import pandas as pd
n = 0
data = pd.read_excel("/content/drive/MyDrive/Trabajo Fin de Grado/Final-Degree-Project/Process Dataframes/Facts.xlsx")
# data = pd.read_excel("/content/drive/MyDrive/TFG/Traductor/RedditES.xlsx", index_col=0)
for i in range(len(data)) :
  prueba = {"id": n, "fact":data.loc[i, "Fact"], "factES":data.loc[i, "FactES"], "holiday":data.loc[i, "Holiday"], "topic":data.loc[i, "Topic"]}
  mong.insert_one(prueba)
  n = n + 1
