# %%
# !pip install pymongo[srv]
# !pip install dnspython
# !pip install pandas
# !pip install -U deep_translator
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 269 kB 6.9 MB/s
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 128 kB 12.6 MB/s
# ...
#   Attempting uninstall: beautifulsoup4
#     Found existing installation: beautifulsoup4 4.6.3
#     Uninstalling beautifulsoup4-4.6.3:
#       Successfully uninstalled beautifulsoup4-4.6.3
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pymongo
from pymongo import MongoClient

client = MongoClient("mongodb+srv://garrachonr:129678@cluster0.p1uwe.mongodb.net/skill?retryWrites=true&w=majority")
db = client.Tomas
mong = db.Riddles

# %%
import pandas as pd
n = 0
data = pd.read_excel("/content/drive/MyDrive/Trabajo Fin de Grado/Final-Degree-Project/Process Dataframes/Riddle.xlsx")
# data = pd.read_excel("/content/drive/MyDrive/TFG/Traductor/RedditES.xlsx", index_col=0)
for i in range(len(data)) :
  prueba = {"id": n, "riddle":data.loc[i, "Riddle"], "answer":data.loc[i, "Answer"], "adivinanza":data.loc[i, "Adivinanza"], "respuesta":data.loc[i, "Respuesta"]}
  mong.insert_one(prueba)
  n = n + 1
