# %%
# !pip install pymongo[srv]
# !pip install dnspython
# !pip install pandas
# Out:
# ...
#      |████████████████████████████████| 269 kB 15.5 MB/s
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pymongo
from pymongo import MongoClient

client = MongoClient("mongodb+srv://garrachonr:129678@cluster0.p1uwe.mongodb.net/skill?retryWrites=true&w=majority")
db = client.Tomas
mong = db.Wiki

# %%
import pandas as pd
n = 0
data = pd.read_excel("/content/drive/MyDrive/Trabajo Fin de Grado/Final-Degree-Project/Process Dataframes/Wiki.xlsx")
for i in range(len(data)) :
  prueba = {"id": n, "title":data.loc[i, "Title"], "summary":data.loc[i, "Summary"], "summaryES":data.loc[i, "SummaryES"], "topic":data.loc[i, "Topic"]}
  mong.insert_one(prueba)
  n = n + 1
