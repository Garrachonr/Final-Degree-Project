# %%
# !pip install git+https://github.com/PrithivirajDamodaran/Parrot.git
# !pip install transformers
# !pip install sentence_transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Cloning https://github.com/PrithivirajDamodaran/Parrot.git to /tmp/pip-req-build-d41p6b4v
#   Running command git clone -q https://github.com/PrithivirajDamodaran/Parrot.git /tmp/pip-req-build-d41p6b4v
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#Check similatiries between two strings
import re
from sentence_transformers import SentenceTransformer, util
model = SentenceTransformer('all-mpnet-base-v2')

def similar(a, b):
  #return re.findall("\d+\.\d+", str(util.dot_score(a, b)))[0]
  first = model.encode(a)
  second = model.encode(b)
  return util.dot_score(first, second)

# %%
import pandas as pd
from transformers import pipeline

#Importar PARROT

from parrot import Parrot
import torch
import warnings
warnings.filterwarnings("ignore")

#Generar una semilla para la recreación de las frases
def random_state(seed):
  torch.manual_seed(seed)
  if torch.cuda.is_available():
    torch.cuda.manual_seed_all(seed)

random_state(1234)

#Cargar el modelo parrot
parrot = Parrot(model_tag="prithivida/parrot_paraphraser_on_T5", use_gpu=False)

# %%
#Create Dataset
dat = {"Phrase" : ["prueba"], "Paraphrase":["year"], "Relación Semántica": ["prueba"], "Bleu": ["prueba"]}
post = pd.DataFrame(dat)
post.to_excel("/content/drive/MyDrive/Trabajo Fin de Grado/Final-Degree-Project/Benchmarks/ParaphraserBenchmark.xlsx")

# %%
# !pip install evaluate
import evaluate

text = "Hi again, what would you like to do today?"
text = [text]
para_phrases = parrot.augment(input_phrase=text[0], max_return_phrases = 3, do_diverse=True)
for i in para_phrases:
  data = [i[0]]
bleu = evaluate.load("bleu")
reference = [text]
results = bleu.compute(predictions=data, references=reference)
prueba = {"Phrase":text[0], "Paraphrase": data[0], "Relación Semántica":similar(text, data[0])[0][0].item(), "Bleu":results["bleu"]}
post = post.append(prueba, ignore_index=True)

text = "Good afternoon, how are you on a day like this?"
text = [text]
para_phrases = parrot.augment(input_phrase=text[0], max_return_phrases = 3, do_diverse=True)
for i in para_phrases:
  data = [i[0]]
bleu = evaluate.load("bleu")
reference = [text]
results = bleu.compute(predictions=data, references=reference)
prueba = {"Phrase":text[0], "Paraphrase": data[0], "Relación Semántica":similar(text, data[0])[0][0].item(), "Bleu":results["bleu"]}
post = post.append(prueba, ignore_index=True)

text = "Here is your answer, hope you enjoy it"
text = [text]
para_phrases = parrot.augment(input_phrase=text[0], max_return_phrases = 3, do_diverse=True)
for i in para_phrases:
  data = [i[0]]
bleu = evaluate.load("bleu")
reference = [text]
results = bleu.compute(predictions=data, references=reference)
prueba = {"Phrase":text[0], "Paraphrase": data[0], "Relación Semántica":similar(text, data[0])[0][0].item(), "Bleu":results["bleu"]}
post = post.append(prueba, ignore_index=True)

text = "Let´s continue, what is currently your field of study?"
text = [text]
para_phrases = parrot.augment(input_phrase=text[0], max_return_phrases = 3, do_diverse=True)
for i in para_phrases:
  data = [i[0]]
bleu = evaluate.load("bleu")
reference = [text]
results = bleu.compute(predictions=data, references=reference)
prueba = {"Phrase":text[0], "Paraphrase": data[0], "Relación Semántica":similar(text, data[0])[0][0].item(), "Bleu":results["bleu"]}
post = post.append(prueba, ignore_index=True)

text = "Im glad to ear you again, how are you?"
text = [text]
para_phrases = parrot.augment(input_phrase=text[0], max_return_phrases = 3, do_diverse=True)
for i in para_phrases:
  data = [i[0]]
bleu = evaluate.load("bleu")
reference = [text]
results = bleu.compute(predictions=data, references=reference)
prueba = {"Phrase":text[0], "Paraphrase": data[0], "Relación Semántica":similar(text, data[0])[0][0].item(), "Bleu":results["bleu"]}
post = post.append(prueba, ignore_index=True)

text = "I don´t remember your name, I think you haven´t told me"
text = [text]
para_phrases = parrot.augment(input_phrase=text[0], max_return_phrases = 3, do_diverse=True)
for i in para_phrases:
  data = [i[0]]
bleu = evaluate.load("bleu")
reference = [text]
results = bleu.compute(predictions=data, references=reference)
prueba = {"Phrase":text[0], "Paraphrase": data[0], "Relación Semántica":similar(text, data[0])[0][0].item(), "Bleu":results["bleu"]}
post = post.append(prueba, ignore_index=True)

text = "Can you tell me your name so I can remember it?"
text = [text]
para_phrases = parrot.augment(input_phrase=text[0], max_return_phrases = 3, do_diverse=True)
for i in para_phrases:
  data = [i[0]]
bleu = evaluate.load("bleu")
reference = [text]
results = bleu.compute(predictions=data, references=reference)
prueba = {"Phrase":text[0], "Paraphrase": data[0], "Relación Semántica":similar(text, data[0])[0][0].item(), "Bleu":results["bleu"]}
post = post.append(prueba, ignore_index=True)

text = "How are you today? What would yo like to do today"
text = [text]
para_phrases = parrot.augment(input_phrase=text[0], max_return_phrases = 3, do_diverse=True)
for i in para_phrases:
  data = [i[0]]
bleu = evaluate.load("bleu")
reference = [text]
results = bleu.compute(predictions=data, references=reference)
prueba = {"Phrase":text[0], "Paraphrase": data[0], "Relación Semántica":similar(text, data[0])[0][0].item(), "Bleu":results["bleu"]}
post = post.append(prueba, ignore_index=True)

text = "It´s nice to hear you agai. You are so close to finish with your study and take the exam. Good luck with it!"
text = [text]
para_phrases = parrot.augment(input_phrase=text[0], max_return_phrases = 3, do_diverse=True)
for i in para_phrases:
  data = [i[0]]
bleu = evaluate.load("bleu")
reference = [text]
results = bleu.compute(predictions=data, references=reference)
prueba = {"Phrase":text[0], "Paraphrase": data[0], "Relación Semántica":similar(text, data[0])[0][0].item(), "Bleu":results["bleu"]}
post = post.append(prueba, ignore_index=True)

text = "Congratulations! you have finished your sutudy for today, now it is time to relax"
text = [text]
para_phrases = parrot.augment(input_phrase=text[0], max_return_phrases = 3, do_diverse=True)
for i in para_phrases:
  data = [i[0]]
bleu = evaluate.load("bleu")
reference = [text]
results = bleu.compute(predictions=data, references=reference)
prueba = {"Phrase":text[0], "Paraphrase": data[0], "Relación Semántica":similar(text, data[0])[0][0].item(), "Bleu":results["bleu"]}
post = post.append(prueba, ignore_index=True)

text = "Now that you have finished your relax interval, it is time for study again, let´´s go"
text = [text]
para_phrases = parrot.augment(input_phrase=text[0], max_return_phrases = 3, do_diverse=True)
for i in para_phrases:
  data = [i[0]]
bleu = evaluate.load("bleu")
reference = [text]
results = bleu.compute(predictions=data, references=reference)
prueba = {"Phrase":text[0], "Paraphrase": data[0], "Relación Semántica":similar(text, data[0])[0][0].item(), "Bleu":results["bleu"]}
post = post.append(prueba, ignore_index=True)

text = "Now that you have finished your relax interval, it is time to study again, let´´s go"
text = [text]
para_phrases = parrot.augment(input_phrase=text[0], max_return_phrases = 3, do_diverse=True)
for i in para_phrases:
  data = [i[0]]
bleu = evaluate.load("bleu")
reference = [text]
results = bleu.compute(predictions=data, references=reference)
prueba = {"Phrase":text[0], "Paraphrase": data[0], "Relación Semántica":similar(text, data[0])[0][0].item(), "Bleu":results["bleu"]}
post = post.append(prueba, ignore_index=True)

text = "I can do a lot of things, like help you to study or maybe tell you some interesting facts"
text = [text]
para_phrases = parrot.augment(input_phrase=text[0], max_return_phrases = 3, do_diverse=True)
for i in para_phrases:
  data = [i[0]]
bleu = evaluate.load("bleu")
reference = [text]
results = bleu.compute(predictions=data, references=reference)
prueba = {"Phrase":text[0], "Paraphrase": data[0], "Relación Semántica":similar(text, data[0])[0][0].item(), "Bleu":results["bleu"]}
post = post.append(prueba, ignore_index=True)

text = "If you have any doubts abaout what you can do, just ask me for it!"
text = [text]
para_phrases = parrot.augment(input_phrase=text[0], max_return_phrases = 3, do_diverse=True)
for i in para_phrases:
  data = [i[0]]
bleu = evaluate.load("bleu")
reference = [text]
results = bleu.compute(predictions=data, references=reference)
prueba = {"Phrase":text[0], "Paraphrase": data[0], "Relación Semántica":similar(text, data[0])[0][0].item(), "Bleu":results["bleu"]}
post = post.append(prueba, ignore_index=True)

text = "I am not sure what you have said, can you ask me anything else? if not, ask me for doubts"
text = [text]
para_phrases = parrot.augment(input_phrase=text[0], max_return_phrases = 3, do_diverse=True)
for i in para_phrases:
  data = [i[0]]
bleu = evaluate.load("bleu")
reference = [text]
results = bleu.compute(predictions=data, references=reference)
prueba = {"Phrase":text[0], "Paraphrase": data[0], "Relación Semántica":similar(text, data[0])[0][0].item(), "Bleu":results["bleu"]}
post = post.append(prueba, ignore_index=True)

text = "I don´t know what you want, can´t you tell me more clearly or in another way?"
text = [text]
para_phrases = parrot.augment(input_phrase=text[0], max_return_phrases = 3, do_diverse=True)
for i in para_phrases:
  data = [i[0]]
bleu = evaluate.load("bleu")
reference = [text]
results = bleu.compute(predictions=data, references=reference)
prueba = {"Phrase":text[0], "Paraphrase": data[0], "Relación Semántica":similar(text, data[0])[0][0].item(), "Bleu":results["bleu"]}
post = post.append(prueba, ignore_index=True)

text = "Here is your joke, hope you have a big laught with it. If you want anything else, just ask for it!"
text = [text]
para_phrases = parrot.augment(input_phrase=text[0], max_return_phrases = 3, do_diverse=True)
for i in para_phrases:
  data = [i[0]]
bleu = evaluate.load("bleu")
reference = [text]
results = bleu.compute(predictions=data, references=reference)
prueba = {"Phrase":text[0], "Paraphrase": data[0], "Relación Semántica":similar(text, data[0])[0][0].item(), "Bleu":results["bleu"]}
post = post.append(prueba, ignore_index=True)

text = "You can ask me, for example, for jokes, interesing facts or ephemerides. Otherwise, I can tell you how to relax or even play trivial with you"
text = [text]
para_phrases = parrot.augment(input_phrase=text[0], max_return_phrases = 3, do_diverse=True)
for i in para_phrases:
  data = [i[0]]
bleu = evaluate.load("bleu")
reference = [text]
results = bleu.compute(predictions=data, references=reference)
prueba = {"Phrase":text[0], "Paraphrase": data[0], "Relación Semántica":similar(text, data[0])[0][0].item(), "Bleu":results["bleu"]}
post = post.append(prueba, ignore_index=True)

text = "If you want to relax or distract from your sudies, you can ask me how to do it or to play trivial"
text = [text]
para_phrases = parrot.augment(input_phrase=text[0], max_return_phrases = 3, do_diverse=True)
for i in para_phrases:
  data = [i[0]]
bleu = evaluate.load("bleu")
reference = [text]
results = bleu.compute(predictions=data, references=reference)
prueba = {"Phrase":text[0], "Paraphrase": data[0], "Relación Semántica":similar(text, data[0])[0][0].item(), "Bleu":results["bleu"]}
post = post.append(prueba, ignore_index=True)

text = "Hope you have a good study time, If you want anything else just ask for it!"
text = [text]
para_phrases = parrot.augment(input_phrase=text[0], max_return_phrases = 3, do_diverse=True)
for i in para_phrases:
  data = [i[0]]
bleu = evaluate.load("bleu")
reference = [text]
results = bleu.compute(predictions=data, references=reference)
prueba = {"Phrase":text[0], "Paraphrase": data[0], "Relación Semántica":similar(text, data[0])[0][0].item(), "Bleu":results["bleu"]}
post = post.append(prueba, ignore_index=True)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.

# %%
post.to_excel("/content/drive/MyDrive/Trabajo Fin de Grado/Final-Degree-Project/Benchmarks/ParaphraserBenchmark.xlsx")

# %%
# !pip install evaluate
import evaluate

text = ["Hi again, what would you like to do today?"]
para_phrases = parrot.augment(input_phrase=text[0], max_return_phrases = 3, do_diverse=True)
for i in para_phrases:
  data = [i[0]]
bleu = evaluate.load("bleu")
#reference = [[data, text]]
reference = [text]
results = bleu.compute(predictions=data, references=reference)
print(results["bleu"])
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# 0.6872892787909722
